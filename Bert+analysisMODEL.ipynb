# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
elmo_epochs = []
bert_subj_epochs = []
elmo_subj_epochs = []
bert_epochs = []
with open("/content/gdrive/MyDrive/stats/baseline_epochs.txt", "r") as data_file:
    elmo_epochs = data_file.readlines()
with open("/content/gdrive/MyDrive/stats/baseline_plus_epochs.txt", "r") as data_file:
    elmo_subj_epochs = data_file.readlines()
with open("/content/gdrive/MyDrive/stats/bert_normal_epochs.txt", "r") as data_file:
    bert_epochs = data_file.readlines()
with open("/content/gdrive/MyDrive/stats/bert_subjective_epochs.txt", "r") as data_file:
    bert_subj_epochs = data_file.readlines()

# %%
elmo_train_losses = []
elmo_train_accuracies = []
elmo_val_losses = []
elmo_val_accuracies = []

for indx,epoch in enumerate(elmo_epochs):
    epoch_num = indx + 1

    cols = epoch.replace("\n", "").split("- ")
    cols = [i.split() for i in cols]

    elmo_train_losses.append(float(cols[2][1]))
    elmo_train_accuracies.append(float(cols[3][1]))
    elmo_val_losses.append(float(cols[4][1]))
    elmo_val_accuracies.append(float(cols[5][1]))
# Plotting the data
from matplotlib import pyplot as plt

x_points = list(range(1, 101))

plt.figure(figsize=(10, 10))
plt.plot(x_points, elmo_train_losses, label='Training Losses')
plt.plot(x_points, elmo_train_accuracies, label='Training Accuracies')
plt.plot(x_points, elmo_val_losses, label='Validation Losses')
plt.plot(x_points, elmo_val_accuracies, label='Validation Accuracies')
plt.title("ELMo")
plt.legend()
plt.show()

# %%
# Gather data
elmo_subj_train_losses = []
elmo_subj_train_accuracies = []
elmo_subj_val_losses = []
elmo_subj_val_accuracies = []

for indx,epoch in enumerate(elmo_subj_epochs):
    epoch_num = indx + 1

    cols = epoch.replace("\n", "").split("- ")
    cols = [i.split() for i in cols]

    elmo_subj_train_losses.append(float(cols[2][1]))
    elmo_subj_train_accuracies.append(float(cols[3][1]))
    elmo_subj_val_losses.append(float(cols[4][1]))
    elmo_subj_val_accuracies.append(float(cols[5][1]))
# Plotting the data
from matplotlib import pyplot as plt

x_points = list(range(1, 101))

plt.figure(figsize=(10, 10))
plt.plot(x_points, elmo_subj_train_losses, label='Training Losses')
plt.plot(x_points, elmo_subj_train_accuracies, label='Training Accuracies')
plt.plot(x_points, elmo_subj_val_losses, label='Validation Losses')
plt.plot(x_points, elmo_subj_val_accuracies, label='Validation Accuracies')
plt.title("ELMo + Subj")
plt.legend()
plt.show()

# %%
# Gather data
bert_train_losses = []
bert_train_accuracies = []
bert_val_losses = []
bert_val_accuracies = []

for indx,epoch in enumerate(bert_epochs):
    epoch_num = indx + 1

    cols = epoch.replace("\n", "").split("- ")
    cols = [i.split() for i in cols]

    bert_train_losses.append(float(cols[2][1]))
    bert_train_accuracies.append(float(cols[3][1]))
    bert_val_losses.append(float(cols[4][1]))
    bert_val_accuracies.append(float(cols[5][1]))
# Plotting the data
from matplotlib import pyplot as plt

x_points = list(range(1, 101))

plt.figure(figsize=(10, 10))
plt.plot(x_points, bert_train_losses, label='Training Losses')
plt.plot(x_points, bert_train_accuracies, label='Training Accuracies')
plt.plot(x_points, bert_val_losses, label='Validation Losses')
plt.plot(x_points, bert_val_accuracies, label='Validation Accuracies')
plt.title("BERT")
plt.legend()
plt.show()

# %%
# Gather data
bert_subj_train_losses = []
bert_subj_train_accuracies = []
bert_subj_val_losses = []
bert_subj_val_accuracies = []

for indx,epoch in enumerate(bert_subj_epochs):
    epoch_num = indx + 1

    cols = epoch.replace("\n", "").split("- ")
    cols = [i.split() for i in cols]

    bert_subj_train_losses.append(float(cols[2][1]))
    bert_subj_train_accuracies.append(float(cols[3][1]))
    bert_subj_val_losses.append(float(cols[4][1]))
    bert_subj_val_accuracies.append(float(cols[5][1]))
# Plotting the data
from matplotlib import pyplot as plt

x_points = list(range(1, 101))

plt.figure(figsize=(10, 10))
plt.plot(x_points, bert_subj_train_losses, label='Training Losses')
plt.plot(x_points, bert_subj_train_accuracies, label='Training Accuracies')
plt.plot(x_points, bert_subj_val_losses, label='Validation Losses')
plt.plot(x_points, bert_subj_val_accuracies, label='Validation Accuracies')
plt.title("BERT + Subjective")
plt.legend()
plt.show()

# %%
pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 5.2 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 56.1 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 58.6 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 58.3 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 58.4 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=14aeb864cf9ae687129659c2aedb72017d84da014fbc142b79b752b7452b7b98
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
# Successfully installed huggingface-hub-0.11.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.24.0

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Error loading corpus: Package 'corpus' not found in index
# False

# %%
import xml.etree.ElementTree as ET
import random
from math import floor
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize
from tqdm import tqdm
import sys

from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Flatten, Dense, Activation
from keras.layers import Concatenate,Conv1D,MaxPooling1D,BatchNormalization
from keras.models import Model
from keras.callbacks import ModelCheckpoint

import torch
import torch.nn as nn
import torch.nn.functional as F

from sentence_transformers import SentenceTransformer
bert_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

class SentenceCNN(nn.Module):
    def __init__(self, D):
        super(SentenceCNN, self).__init__()

        self.conv_3 = nn.Conv1d(in_channels=D, out_channels=100, kernel_size=3)
        self.conv_4 = nn.Conv1d(in_channels=D, out_channels=100, kernel_size=4)
        self.conv_5 = nn.Conv1d(in_channels=D, out_channels=100, kernel_size=5)

        self.dropout = nn.Dropout(p=0.5)
        self.fc = nn.Linear(300, 1)

    def forward(self, x):
        # x = self.embedding(x)
        x = x.transpose(1,2)
        x3 = F.relu(self.conv_3(x))
        x4 = F.relu(self.conv_4(x))
        x5 = F.relu(self.conv_5(x))
        x3 = nn.MaxPool1d(kernel_size = 38)(x3)
        x4 = nn.MaxPool1d(kernel_size = 37)(x4)
        x5 = nn.MaxPool1d(kernel_size = 36)(x5)
        out = torch.cat([x3, x4, x5], 2)
        out = out.view(out.size(0), -1)
        out = self.dropout(out)
        return self.fc(out)

def conv1d_BN(max_len, embed_size):
    num_filters = 128
    filter_sizes = list(range(2, 7))
    maxpools = []

    inputs = Input(shape=(max_len,embed_size), dtype='float32')

    for i in range(5):
        conv_i = Conv1D(num_filters, kernel_size=(filter_sizes[i]))(inputs)
        act_i = Activation('relu')(conv_i)
        bn_i = BatchNormalization(momentum=0.7)(act_i)
        maxpools.append(MaxPooling1D(pool_size=(max_len - filter_sizes[i]))(bn_i))

    concatenated_tensor = Concatenate()(maxpools)
    flatten = Flatten()(concatenated_tensor)
    output = Dense(units=1, activation='sigmoid')(flatten)

    model = Model(inputs=inputs, outputs=output)
    model.summary()
    model.compile(loss='binary_crossentropy', metrics=['acc'], optimizer='adam')
    return model

articles_xmltree_file = '/content/articles-training-byarticle-20181122.xml'
articles_tree = ET.parse(articles_xmltree_file)
articles_root = articles_tree.getroot()

truth_xmltree_file = '/content/ground-truth-training-byarticle-20181122.xml'
truth_tree = ET.parse(truth_xmltree_file)
truth_root = truth_tree.getroot()

dataset_articles_text = []
dataset_articles_truth_value = []
dataset_articles_id = []

for articles_child, truth_child in zip(articles_root, truth_root):
    articles_attributes = articles_child.attrib
    truth_attributes = truth_child.attrib

    article_text = [p.text for p in articles_child if p.text is not None]
    article_text = " ".join(article_text)

    if truth_attributes["id"] in [
            "0000219", "0000258", "0000364"
            ]:
        continue

    sentences = sent_tokenize(article_text)
    if len(sentences) == 0:
        continue

    # Add the values to their respective lists
    dataset_articles_text.append(article_text.encode('ascii', 'ignore').decode())
    if truth_attributes["hyperpartisan"] == "true":
        dataset_articles_truth_value.append(1)
    else:
        dataset_articles_truth_value.append(0)
    dataset_articles_id.append(truth_attributes["id"])


num_articles = len(dataset_articles_text)

# Store the corresponding indices
training_articles = random.sample(range(num_articles), floor(num_articles*0.8))
testing_articles = [_ for _ in range(num_articles) if _ not in training_articles]

dataset_elmo_embeddings = []
seed = (sys.argv[1])
random.seed(seed)

for i in tqdm(range(len(dataset_articles_text))):

    article_text = dataset_articles_text[i]

    article_sentences = sent_tokenize(article_text)

    article_words = [word_tokenize(sentence) for sentence in article_sentences]
    np.set_printoptions(threshold=sys.maxsize)

    final_embeddings = []
    for sent in article_sentences:
        final_embeddings.append(bert_model.encode(sent))

    final_embeddings = np.array(final_embeddings)

    article_sentences_embeddings = final_embeddings[:200]
    padded_embedding = pad_sequences([article_sentences_embeddings], maxlen=200, dtype='float32')[0]

    dataset_elmo_embeddings.append(padded_embedding)

dataset_elmo_embeddings_np = np.array(dataset_elmo_embeddings)
dataset_articles_id_np = np.array(dataset_articles_id)
dataset_articles_truth_value_np = np.array(dataset_articles_truth_value)

cnn_model = conv1d_BN(200, 384)
checkpoints = ModelCheckpoint(filepath='./models/CNN_elmo_checkpoint.hdf5',
                              verbose=1, monitor='val_acc', save_best_only=True)


history = cnn_model.fit(
        x=dataset_elmo_embeddings_np[training_articles], y=dataset_articles_truth_value_np[training_articles],
        batch_size=32, verbose=1, epochs=100,
        validation_data=(dataset_elmo_embeddings_np[testing_articles], dataset_articles_truth_value_np[testing_articles]),
        callbacks=[checkpoints]
        )

from sklearn.metrics import classification_report

y_pred = cnn_model.predict(dataset_elmo_embeddings_np[testing_articles], batch_size=32, verbose=1)
y_pred = y_pred.flatten()

y_pred_bool = []
for pred in y_pred:
    if pred >= 0.5:
        y_pred_bool.append(1)
    else:
        y_pred_bool.append(0)

y_pred_bool = np.array(y_pred_bool)

print(classification_report(dataset_articles_truth_value_np[testing_articles], y_pred_bool))

cv_score = history.history['val_acc'][-1]

with open("./results.txt", "a") as rf:
    rf.write("==============================\n")
    rf.write(f"Final score of Bert Model for seed = {seed} is {cv_score}\n")

print("Final Score of the Bert Model:", cv_score)
# Out:
# 100%|██████████| 642/642 [01:41<00:00,  6.31it/s]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 384)]   0           []
#
#  conv1d (Conv1D)                (None, 199, 128)     98432       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 198, 128)     147584      ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 197, 128)     196736      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 196, 128)     245888      ['input_1[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 195, 128)     295040      ['input_1[0][0]']
#
#  activation (Activation)        (None, 199, 128)     0           ['conv1d[0][0]']
#
#  activation_1 (Activation)      (None, 198, 128)     0           ['conv1d_1[0][0]']
#
#  activation_2 (Activation)      (None, 197, 128)     0           ['conv1d_2[0][0]']
#
#  activation_3 (Activation)      (None, 196, 128)     0           ['conv1d_3[0][0]']
#
#  activation_4 (Activation)      (None, 195, 128)     0           ['conv1d_4[0][0]']
#
#  batch_normalization (BatchNorm  (None, 199, 128)    512         ['activation[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 198, 128)    512         ['activation_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 197, 128)    512         ['activation_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 196, 128)    512         ['activation_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 195, 128)    512         ['activation_4[0][0]']
#  rmalization)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 128)       0           ['batch_normalization[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 1, 128)      0           ['batch_normalization_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 1, 128)      0           ['batch_normalization_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 1, 128)      0           ['batch_normalization_3[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 1, 128)      0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 1, 640)       0           ['max_pooling1d[0][0]',
#                                                                   'max_pooling1d_1[0][0]',
#                                                                   'max_pooling1d_2[0][0]',
#                                                                   'max_pooling1d_3[0][0]',
#                                                                   'max_pooling1d_4[0][0]']
#
#  flatten (Flatten)              (None, 640)          0           ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 1)            641         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 986,881
# Trainable params: 985,601
# Non-trainable params: 1,280
# __________________________________________________________________________________________________
# Epoch 1/100
# 17/17 [==============================] - ETA: 0s - loss: 2.0904 - acc: 0.6569
# Epoch 1: val_acc improved from -inf to 0.64341, saving model to ./models/CNN_elmo_checkpoint.hdf5
# 17/17 [==============================] - 8s 59ms/step - loss: 2.0904 - acc: 0.6569 - val_loss: 1.5989 - val_acc: 0.6434
# Epoch 2/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0
val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0126 - acc: 0.9942 - val_loss: 2.1927 - val_acc: 0.6822
# Epoch 42/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0127 - acc: 0.9941
# Epoch 42: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0127 - acc: 0.9942 - val_loss: 2.0449 - val_acc: 0.6822
# Epoch 43/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0126 - acc: 0.9941
# Epoch 43: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0126 - acc: 0.9942 - val_loss: 2.4762 - val_acc: 0.6899
# Epoch 44/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0125 - acc: 0.9941
# Epoch 44: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0125 - acc: 0.9942 - val_loss: 2.1479 - val_acc: 0.6589
# Epoch 45/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0123 - acc: 0.9941
# Epoch 45: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 2.0526 - val_acc: 0.6589
# Epoch 46/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0127 - acc: 0.9941
# Epoch 46: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0127 - acc: 0.9942 - val_loss: 1.8360 - val_acc: 0.6899
# Epoch 47/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 47: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.1364 - val_acc: 0.6744
# Epoch 48/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 48: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.3965 - val_acc: 0.6667
# Epoch 49/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0124 - acc: 0.9941
# Epoch 49: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0124 - acc: 0.9942 - val_loss: 2.1590 - val_acc: 0.6589
# Epoch 50/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 50: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0121 - acc: 0.9942 - val_loss: 2.0336 - val_acc: 0.6434
# Epoch 51/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 51: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.4278 - val_acc: 0.6589
# Epoch 52/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 52: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 1.9689 - val_acc: 0.6744
# Epoch 53/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0124 - acc: 0.9941
# Epoch 53: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0124 - acc: 0.9942 - val_loss: 2.0897 - val_acc: 0.6512
# Epoch 54/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0120 - acc: 0.9941
# Epoch 54: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0120 - acc: 0.9942 - val_loss: 2.2850 - val_acc: 0.6434
# Epoch 55/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 55: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.1672 - val_acc: 0.6667
# Epoch 56/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0123 - acc: 0.9941
# Epoch 56: val_acc did not improve from 0.68992
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 1.9794 - val_acc: 0.6899
# Epoch 57/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0120 - acc: 0.9941
# Epoch 57: val_acc improved from 0.68992 to 0.70543, saving model to ./models/CNN_elmo_checkpoint.hdf5
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0120 - acc: 0.9942 - val_loss: 1.6827 - val_acc: 0.7054
# Epoch 58/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0123 - acc: 0.9941
# Epoch 58: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 2.0400 - val_acc: 0.6589
# Epoch 59/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0123 - acc: 0.9941
# Epoch 59: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 1.9610 - val_acc: 0.6667
# Epoch 60/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0124 - acc: 0.9941
# Epoch 60: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 2.0787 - val_acc: 0.6744
# Epoch 61/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.
val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 2.3256 - val_acc: 0.6744
# Epoch 82/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 82: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.4847 - val_acc: 0.6822
# Epoch 83/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0132 - acc: 0.9941
# Epoch 83: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0132 - acc: 0.9942 - val_loss: 2.2538 - val_acc: 0.6667
# Epoch 84/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 84: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.5837 - val_acc: 0.6357
# Epoch 85/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0098 - acc: 0.9961
# Epoch 85: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0121 - acc: 0.9942 - val_loss: 2.5646 - val_acc: 0.6589
# Epoch 86/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0124 - acc: 0.9941
# Epoch 86: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0124 - acc: 0.9942 - val_loss: 2.4859 - val_acc: 0.6434
# Epoch 87/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0123 - acc: 0.9941
# Epoch 87: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 2.5408 - val_acc: 0.6667
# Epoch 88/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0127 - acc: 0.9941
# Epoch 88: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0127 - acc: 0.9942 - val_loss: 2.1703 - val_acc: 0.6899
# Epoch 89/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0126 - acc: 0.9941
# Epoch 89: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0126 - acc: 0.9942 - val_loss: 2.4462 - val_acc: 0.6357
# Epoch 90/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0127 - acc: 0.9941
# Epoch 90: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0127 - acc: 0.9942 - val_loss: 2.3784 - val_acc: 0.6434
# Epoch 91/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0121 - acc: 0.9941
# Epoch 91: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0121 - acc: 0.9942 - val_loss: 2.2909 - val_acc: 0.6434
# Epoch 92/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0127 - acc: 0.9941
# Epoch 92: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0127 - acc: 0.9942 - val_loss: 4.9570 - val_acc: 0.5659
# Epoch 93/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0126 - acc: 0.9941
# Epoch 93: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0126 - acc: 0.9942 - val_loss: 2.2159 - val_acc: 0.6667
# Epoch 94/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0124 - acc: 0.9941
# Epoch 94: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0123 - acc: 0.9942 - val_loss: 2.1504 - val_acc: 0.6512
# Epoch 95/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 95: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.2621 - val_acc: 0.6512
# Epoch 96/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0120 - acc: 0.9941
# Epoch 96: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0120 - acc: 0.9942 - val_loss: 2.5034 - val_acc: 0.6822
# Epoch 97/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 97: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0122 - acc: 0.9942 - val_loss: 2.1704 - val_acc: 0.6589
# Epoch 98/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0119 - acc: 0.9941
# Epoch 98: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0119 - acc: 0.9942 - val_loss: 2.0326 - val_acc: 0.6822
# Epoch 99/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0121 - acc: 0.9941
# Epoch 99: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0121 - acc: 0.9942 - val_loss: 2.6722 - val_acc: 0.6434
# Epoch 100/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0122 - acc: 0.9941
# Epoch 100: val_acc did not improve from 0.70543
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0121 - acc: 0.9942 - val_loss: 2.3657 - val_acc: 0.6357
# 5/5 [==============================] - 0s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.64      0.82      0.72        73
#            1       0.63      0.39      0.48        56
#
#     accuracy                           0.64       129
#    macro avg       0.63      0.61      0.60       129
# weighted avg       0.63      0.64      0.62       129
#
# Final Score of the Bert Model: 0.6356589198112488
